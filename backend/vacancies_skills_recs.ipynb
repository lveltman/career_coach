# %%
import re
import faiss
import numpy as np
import pandas as pd
from collections import Counter
import networkx as nx
from sentence_transformers import SentenceTransformer

# %%
df_vacancies = pd.read_parquet('../data_artefacts')

# %%
df_vacancies
# Out:
#        vacancy_id                                              title    city  \
# 0       124523955                                  Менеджер продукта  Москва
# 1       124826328               Delivery Manager / Деливери менеджер  Москва
# 2       124964211  DevOps-инженер в команду User Storage & Policy...  Москва
# 3       124374678              Системный аналитик/Аналитик данных ML  Москва
# 4       123978202                             PowerPlatform Engineer  Москва
# ...           ...                                                ...     ...
# 17571   124789341  Преподаватель курса Backend-разработка (разраб...  Москва
# 17572   123899058                       Оператор по обработке заявок  Москва
# 17573   125035681                   Менеджер проекта (строительство)  Москва
# 17574   124426292                 DataOps/DevOps инженер на DataLake  Москва
# 17575   123895928                      Помощник Руководителя проекта  Москва
#
#                                                 keywords  \
# 0      Ты любишь общаться с людьми и умеешь находить ...
# 1      Опыт управления ИТ-проектами от 5 лет (планиро...
# 2      Понимание основ сетевых технологий (стек TCP/I...
# 3      Знание основ http-запросов, опыт работы с <hig...
# 4      Strong skills in algorithms, <highlighttext>da...
# ...                                                  ...
# 17571  Знание или опыт работы как минимум в одном из ...
# 17572  Имеете базовые навыки работы с ПК (Google Docs...
# 17573  Опыт работы от 1 года в аналогичной должности ...
# 17574  Опыта работы по направлению DataOps/DevOps/<hi...
# 17575  Высшее техническое образование. Опыт работы от...
#
#                                                   skills  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      [Power BI, MS SharePoint, MS SQL Server, Azure...
# ...                                                  ...
# 17571  [Python, C++, С#, ADO.NET, ООП, SQL, UML, Архи...
# 17572                                                 []
# 17573  [Деловая переписка, Организаторские навыки, Де...
# 17574  [Linux, Kubernetes, S3, Spark, Impala, Hive, T...
# 17575                                                 []
#
#                                                  company  \
# 0                                   Дальневосточный банк
# 1                                         Брайт Эйдженси
# 2                                            WILDBERRIES
# 3      Центр Информационных технологий Роскадастр-Инф...
# 4                                                 ACCESA
# ...                                                  ...
# 17571  Компьютерная академия TOP (Компьютерная Академ...
# 17572                                    Ирбис Аналитика
# 17573                                        Кипарис МСК
# 17574                                         Ингосстрах
# 17575                                       СоюзДонСтрой
#
#                                                 industry          experience  \
# 0                                                   Банк  От 1 года до 3 лет
# 1                                     Кадровые агентства       От 3 до 6 лет
# 2                                       Интернет-магазин       От 3 до 6 лет
# 3                                                Unknown  От 1 года до 3 лет
# 4      Системная интеграция,  автоматизации технологи...       От 3 до 6 лет
# ...                                                  ...                 ...
# 17571                             Вуз, ссуз колледж, ПТУ  От 1 года до 3 лет
# 17572                Разработка программного обеспечения           Нет опыта
# 17573                                            Unknown  От 1 года до 3 лет
# 17574                       Страхование, перестрахование       От 3 до 6 лет
# 17575                                            Unknown  От 1 года до 3 лет
#
#        salary_from  salary_to salary_currency         salary_str  \
# 0          80000.0        NaN             RUR         80000- RUR
# 1              NaN        NaN            None     з/п не указана
# 2              NaN        NaN            None     з/п не указана
# 3         170000.0        NaN             RUR        170000- RUR
# 4              NaN        NaN            None     з/п не указана
# ...            ...        ...             ...                ...
# 17571      50000.0        NaN             RUR         50000- RUR
# 17572      40000.0    60000.0             RUR    40000-60000 RUR
# 17573      75000.0    75000.0             RUR    75000-75000 RUR
# 17574          NaN        NaN            None     з/п не указана
# 17575     100000.0   120000.0             RUR  100000-120000 RUR
#
#                                    url              published_at  \
# 0      https://hh.ru/vacancy/124523955 2025-08-27 05:28:36+00:00
# 1      https://hh.ru/vacancy/124826328 2025-09-03 11:34:11+00:00
# 2      https://hh.ru/vacancy/124964211 2025-09-05 16:00:35+00:00
# 3      https://hh.ru/vacancy/124374678 2025-08-22 11:36:06+00:00
# 4      https://hh.ru/vacancy/123978202 2025-08-12 14:03:02+00:00
# ...                                ...                       ...
# 17571  https://hh.ru/vacancy/124789341 2025-09-02 15:47:05+00:00
# 17572  https://hh.ru/vacancy/123899058 2025-09-07 10:24:25+00:00
# 17573  https://hh.ru/vacancy/125035681 2025-09-08 11:47:24+00:00
# 17574  https://hh.ru/vacancy/124426292 2025-08-25 08:06:50+00:00
# 17575  https://hh.ru/vacancy/123895928 2025-09-07 09:47:31+00:00
#
#          source_vacancy
# 0       Product Manager
# 1      Machine Learning
# 2      Python Developer
# 3           Web Analyst
# 4         Data Engineer
# ...                 ...
# 17571  Python Developer
# 17572   Аналитик данных
# 17573   Project Manager
# 17574     Data Engineer
# 17575   Project Manager
#
# [17576 rows x 15 columns]

# %%
model = SentenceTransformer('efederici/sentence-bert-base')

def normalize_text(text: str) -> str:
    if not isinstance(text, str):
        return ""
    text = text.lower().strip()
    text = re.sub(r"[^a-zа-я0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text)
    return text

vacancy_texts = [
    normalize_text(
        f"{row['title']} {row['company']} {', '.join(row['skills'])} {row['experience']} {row['keywords']}"
    )
    for _, row in df_vacancies.iterrows()
]

vacancy_embeddings = model.encode(vacancy_texts, convert_to_numpy=True).astype("float32")
vacancy_embeddings /= np.linalg.norm(vacancy_embeddings, axis=1, keepdims=True)

# %%
# FAISS индекс
dim = vacancy_embeddings.shape[1]
faiss_index = faiss.IndexHNSWFlat(dim, 32)  # HNSW для быстрого поиска
faiss_index.add(vacancy_embeddings)

# %%
G = nx.DiGraph()
position_nodes = []

for i, row in df_vacancies.iterrows():
    pos_node = row["title"]
    position_nodes.append(pos_node)
    
    # Вершины вакансии
    G.add_node(pos_node, type="position", vacancy_id=row["vacancy_id"], 
               company=row["company"], experience=row["experience"],
               salary=row["salary_str"], industry=row["industry"],
               embedding=vacancy_embeddings[i])
    
    if row["company"]:
        G.add_node(row["company"], type="company")
        G.add_edge(pos_node, row["company"])
    if row["experience"]:
        G.add_node(row["experience"], type="level")
        G.add_edge(pos_node, row["experience"])
    if row["industry"]:
        G.add_node(row["industry"], type="domain")
        G.add_edge(pos_node, row["industry"])

    # Навыки
    skills_arr = row["skills"]
    if isinstance(skills_arr, (list, np.ndarray)):
        for skill in skills_arr:
            skill = str(skill).strip()
            if skill:
                G.add_node(skill, type="skill")
                G.add_edge(pos_node, skill)  # position → skill
                G.add_edge(skill, pos_node)  # skill → position

# %%
def recommend_vacancies(user_text, top_k=5, top_career=1, min_skill_freq=2, top_skills=10):
    user_vector = model.encode([normalize_text(user_text)], convert_to_numpy=True).astype("float32")
    user_vector /= np.linalg.norm(user_vector, axis=1, keepdims=True)
    # Поиск топ-K вакансий по FAISS
    distances, indices = faiss_index.search(user_vector, top_k)
    
    recommendations = []
    career_paths = set()
    all_neighbor_skills = []
    
    for idx in indices[0]:
        node = position_nodes[idx]
        n_data = G.nodes[node]

        skills = [s for s in G.successors(node) if G.nodes[s]["type"]=="skill"]
        
        recommendations.append({
            "title": node,
            "company": n_data["company"],
            "experience": n_data["experience"],
            "salary": n_data["salary"],
            "industry": n_data["industry"],
            "skills": skills
        })
        
        # Топ-N похожих позиций через навыки
        for skill in skills:
            neighbors = [pos for pos in G.successors(skill) if G.nodes[pos]["type"]=="position" and pos != node]
            if neighbors:
                # Сортируем по косинусной близости эмбеды
                neighbor_embeddings = np.array([G.nodes[p]["embedding"] for p in neighbors]).astype("float32")
                sims = neighbor_embeddings @ user_vector.T
                # Берем только top_career ближайших соседей
                top_idx = np.argsort(-sims.ravel())[:top_career]
                for i in top_idx:
                    neighbor_pos = neighbors[i]
                    career_paths.add(neighbor_pos)
                    
                    # Вытаскиваем навыки у соседа
                    neighbor_skills = [
                        s for s in G.successors(neighbor_pos) if G.nodes[s]["type"] == "skill"
                    ]
                    all_neighbor_skills.extend(neighbor_skills)
    
    # Фильтрация навыков по частоте
    skill_counts = Counter(all_neighbor_skills)
    filtered_skills = [s for s, c in skill_counts.items() if c >= min_skill_freq]
    
    # Ограничиваем топ N по частоте
    expanded_skills = [s for s, _ in skill_counts.most_common(top_skills) if s in filtered_skills]

    return recommendations, expanded_skills, list(career_paths)

user_query = "ML engineer с опытом PyTorch 1 год"
recs, skills, paths = recommend_vacancies(user_query)

print("Рекомендованные вакансии (ближайшие к user vector через faiss:")
for r in recs:
    print(r)

print("\nНавыки для апгрейда (через граф):")
print(skills)

print("\nПотенциальные карьерные переходы:")
print(paths)
# Out:
# Рекомендованные вакансии (ближайшие к user vector через faiss:
# {'title': 'ML Engineer', 'company': 'Эвотор', 'experience': 'От 3 до 6 лет', 'salary': 'з/п не указана', 'industry': 'Разработка программного обеспечения', 'skills': ['Python', 'PyTorch', 'Linux', 'Git', 'Computer Vision', 'MLOps', 'Machine Learning', 'ML', 'Математическая статистика', 'Алгоритмы и структуры данных', 'SQL', 'Машинное обучение', 'Data Science', 'NLP', 'Английский язык', 'MySQL', 'C/C++', 'NLU', 'Clickhouse', 'Теория вероятностей', 'Классическое машинное обучение', 'A/B тесты', 'PySpark', 'TensorFlow', 'Базы данных', 'n8n', 'AI', 'Deep Learning', 'Docker', 'ООП', 'LLM', 'RAG', 'Langchain', 'FastAPI']}
# {'title': 'Data scientist', 'company': 'Страховая компания Freedom Insurance', 'experience': 'От 3 до 6 лет', 'salary': 'з/п не указана', 'industry': 'Страхование, перестрахование', 'skills': ['Python', 'pandas', 'Numpy', 'Анализ временных рядов', 'Машинное обучение', 'ML', 'SQL', 'Анализ данных', 'Базы данных']}
# {'title': 'Data Scientist', 'company': 'Hawking Bros', 'experience': 'От 3 до 6 лет', 'salary': '-180000 RUR', 'industry': 'Интернет-компания (поисковики, платежные системы, соц.сети, информационно-познавательные и развлекательные ресурсы, продвижение сайтов и прочее)', 'skills': ['Python', 'NLP', 'CV', 'PyTorch', 'OpenCV', 'NLTK', 'Linux', 'VSCode', 'JupyterLab', 'SQL', 'Алгоритмы и структуры данных', 'Computer Vision', 'Математическая статистика', 'Анализ данных', 'Big Data', 'XGBoost', 'Numpy', 'CatBoost', 'SciPy', 'Matplotlib', 'Deep Learning', 'Jupyter Notebook', 'PyCharm', 'PostgreSQL', 'Hadoop', 'Теория вероятностей', 'recsys', 'postgres', 'ml', 'data scince', 'Kubernetes', 'MLflow', 'Spark', 'MS SQL', 'ELISA', 'pandas', 'FastAPI', 'Apache Airflow', 'CI/CD', 'Docker', 'NLP Engineer', 'TensorFlow', 'МСФО', 'Базовые знания SQL', 'Уверенный пользователь MS Office', 'Работа в условиях многозадачности', 'ORACLE', 'PySpark', 'MySQL', 'Английский язык', 'ML', 'Data Science', 'Keras', 'Ad Hoc Analysis', 'Исследовательский анализ данных', 'Power BI', 'MS PowerPoint', 'UML', 'MS SQL Server', 'Машинное обучение', 'Классическое машинное обучение', 'TypeScript', 'Микросервисная архитектура', 'API', 'JupyterHub', 'Scikit-learn']}
# {'title': 'Middle ML Engineer', 'company': 'Alif Uzbekistan', 'experience': 'От 1 года до 3 лет', 'salary': 'з/п не указана', 'industry': 'Разработка программного обеспечения', 'skills': ['Python', 'AI/ML', 'Английский язык', 'PyTorch', 'TensorFlow', 'Clickhouse', 'Apache Airflow']}
# {'title': 'Data Scientist / ML Engineer', 'company': 'РБ', 'experience': 'От 3 до 6 лет', 'salary': '250000-300000 RUR', 'industry': 'Издательская деятельность', 'skills': ['Python', 'SQL', 'Clickhouse', 'CatBoost', 'XGBoost']}
#
# Навыки для апгрейда (через граф):
# ['Python', 'SQL', 'Git', 'LLM', 'PyTorch', 'NLP', 'Linux', 'ML', 'Clickhouse', 'Docker']
#
# Потенциальные карьерные переходы:
# ['Lead ML Engineer', 'Quantitative Researcher', 'Team Lead\u200b\u200b\u200b\u200b\u200b\u200b\u200b\xa0Data Scientist (Search & Recommendation)', 'Инженер по нагрузочному тестированию', 'ИТ лидер DS/ML (Домен ИИ)', 'ML Engineer (Code Assistant ML RnD)', 'Machine Learning Engineer', 'Старший Data Scientist, Эффективность рекламы', 'LLM Researcher / Engineer', 'Ведущий бизнес-аналитик', 'Data Scientist / ML Engineer', 'IT Project Manager', 'ML-инженер LLM', 'Chief Data Officer', 'ML-инженер (Classic ML, CVM)', 'ML Ops', 'Middle AI Engineer', 'ML Engineer/Data Scientist на продукт Ценообразование', 'LLMOps engineer', 'Продуктовый аналитик', 'DevOps Engineer', 'ML-разработчик компилятора нейронных сетей', 'Аналитик данных', 'ML-инженер', 'Разработчик систем аналитики (ETL + Docker)', 'Системный аналитик (Data platform и ML)', 'Data scientist / ML-инженер (NLP, LLM)', 'Преподаватель IT дисциплин', 'Дата-аналитик', 'Системный аналитик (Middle/Senior)', 'ML-Инженер (computer vision)', 'Senior ML-разработчик в команду R&D', 'ML engineer (камеры ФВФ)', 'Senior Machine Learning Engineer', 'ML Engineer (PyTorch, Audio)', 'PHP-разработчик (Getblogger)', 'ML разработчик, группа внутренних ML продуктов', 'Senior ML-engineer, NLP в техподдержке', 'Senior QA Automation Engineer', 'Аналитик медиа / социальных медиа (медиааналитик)', 'Бизнес-аналитик (Аудит)', 'Senior Data Scientist/ML Engineer в команду Чековой аналитики', 'Product analyst (Прайсинг)', 'BI-аналитик', 'ML Engineer ("Search")', 'ML Engineer', 'Бизнес-аналитик (ИТ)', 'ML инженер/Machine Learning engineer (Python)', 'Data Scientist / ML-инженер', 'Senior ML Engineer в немецкую компанию', 'Архитектор безопасности больших данных', 'C++ Developer', 'Системный разработчик MacOS', 'Финансист', 'R&D ML-инженер']
